# %%
from app.GroqAgent import GroqClient
model = GroqClient()
model.build_agent()
# Out:
# (<langgraph.graph.state.CompiledStateGraph at 0x1133db390>,
#  [StructuredTool(name='search_document', description='Search relevant content across all processed documents.', args_schema=<class 'langchain_core.utils.pydantic.search_document'>, func=<function create_document_tools.<locals>.search_document at 0x113478860>),
#   StructuredTool(name='summarize_document', description='Generate a structured summary of a specific document.\nInput should be the exact filename.', args_schema=<class 'langchain_core.utils.pydantic.summarize_document'>, func=<function create_document_tools.<locals>.summarize_document at 0x113478cc0>),
#   StructuredTool(name='search_document_in_file', description='Search within a specific document.', args_schema=<class 'langchain_core.utils.pydantic.search_document_in_file'>, func=<function create_document_tools.<locals>.search_document_in_file at 0x11346b240>)])

# %%
from app.AgentPipeline import SmartDocAssistant
obj = SmartDocAssistant()
obj
# Out:
# Agent ready at initialization: (<langgraph.graph.state.CompiledStateGraph object at 0x1135ad480>, [StructuredTool(name='search_document', description='Search relevant content across all processed documents.', args_schema=<class 'langchain_core.utils.pydantic.search_document'>, func=<function create_document_tools.<locals>.search_document at 0x11353a480>), StructuredTool(name='summarize_document', description='Generate a structured summary of a specific document.\nInput should be the exact filename.', args_schema=<class 'langchain_core.utils.pydantic.summarize_document'>, func=<function create_document_tools.<locals>.summarize_document at 0x113539760>), StructuredTool(name='search_document_in_file', description='Search within a specific document.', args_schema=<class 'langchain_core.utils.pydantic.search_document_in_file'>, func=<function create_document_tools.<locals>.search_document_in_file at 0x11353a020>)])
